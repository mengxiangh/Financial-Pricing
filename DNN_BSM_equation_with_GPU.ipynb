# %%
import numpy as np
import scipy.stats as si
import pandas as pd
import torch

# %%
datasize = 1000000
learning_rate = 0.0001

b_size = 100
epoch = 50

# %%
# BSM model for option pricing

def euro_option(S0, K, T, r, sigma, option_type):
    
    #S0: stock price
    #sigma: volatility
    #K: strike price
    #r: return
    #T: time to maturity
    
    d1 = (np.log(S0/K) + (r + sigma ** 2 * 0.5))/sigma/np.sqrt(T)
    d2 = (np.log(S0/K) + (r - sigma ** 2 * 0.5))/sigma/np.sqrt(T)
    
    if option_type == 'call':
        price = S0 * si.norm.cdf(d1, 0, 1) - K * np.exp(-r * T) * si.norm.cdf(d2, 0, 1)
        
    if option_type == 'put':
        price = K * np.exp(-r * T) * si.norm.cdf(-d2, 0, 1) - S0 * si.norm.cdf(-d1, 0, 1)
        
    return price

# %%
def simulate_price(total_num):
    np.random.seed(42)
    S0 = np.random.rand(total_num) * 100
    K = np.random.randint(50,150,total_num)* 0.01 * S0
    T = np.random.randint(10, 300, total_num)/100
    r = np.random.randint(1, 1000, total_num)/10000
    sigma = np.random.randint(1, 50, total_num)/100
    option_type = np.random.choice(['call','put'], total_num)
    
    option_price_list = []
    
    for i in range(total_num): 
        price = euro_option(S0[i], K[i], T[i], r[i], sigma[i], option_type[i])
        option_price_list.append(price)
        if i%100000 == 1:
            print('finished:', i)
            
    df = pd.DataFrame({'S0': S0,
                       'K': K,
                       'T': T,
                       'r': r,
                       'sigma': sigma,
                       'option_type': option_type,
                       'price': option_price_list})
    return df

# %%
df = simulate_price(datasize)
# Out:
# finished: 1
# finished: 100001
# finished: 200001
# finished: 300001
# finished: 400001
# finished: 500001
# finished: 600001
# finished: 700001
# finished: 800001
# finished: 900001

# %%
from sklearn.model_selection import train_test_split
df_coded = pd.concat([df, pd.get_dummies(df['option_type'])], axis=1).drop(columns='option_type')
df_coded = df_coded[['S0','K','T','r','sigma','call','put','price']]

# %%
train_set, test_set = train_test_split(df_coded, test_size=0.1)

# %%
# define dataset
from torch.utils.data import Dataset, DataLoader

class option_dataset(Dataset):
    def __init__(self, dataset):
        self.dataset = torch.tensor(dataset.values, device = 'cuda: 0')
    def __getitem__(self, index):
        return (self.dataset[:,0:7][index], self.dataset[:,7][index].view(1))
    def __len__(self):
        return self.dataset.shape[0]
    

    
train_dataset = option_dataset(train_set)
test_dataset = option_dataset(test_set)

# %%
train_loader = DataLoader(train_dataset, batch_size = b_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size = b_size, shuffle=True)

# %%
# define NN
import torch.nn as nn
import torch.nn.functional as F
class option_pricing(nn.Module):
    
    def __init__(self):
        super(option_pricing,self).__init__()
        self.fc1 = nn.Linear(7, 128)
        self.fc2 = nn.Linear(128, 1024)
        self.fc3 = nn.Linear(1024, 32)
        self.fc4 = nn.Linear(32, 1).cuda()
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x
net = option_pricing()
net = net.to('cuda: 0')

# %%
import  torch.optim as optim

criterion = nn.MSELoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9 )

# %%
train_loss_list = []
test_loss_list = []
for epoch in range(epoch):
    
    train_running_loss = []
    test_running_loss = []
    
    print('Train:')
    for i, data in enumerate(train_loader):
        inputs,target = data

        #X, Y = Variable(torch.FloatTensor([X]), requires_grad=True), Variable(torch.FloatTensor([Y]), requires_grad=False)
        optimizer.zero_grad()
        outputs = net(inputs.float())
        loss = criterion(outputs, target.float())
        loss.backward()
        optimizer.step()
        
        
        
        train_running_loss.append(loss.item()/b_size)
         
        if i%5000 == 0:
            print('epoch {}, batches {}, running_loss {}'.format(epoch+1, i+1, loss.item()/b_size))
          
            
    train_loss_list.append(np.mean(train_running_loss))
            
        
            
           
    for j, data2 in enumerate(test_loader):
        test_inputs, test_target = data2
        test_outputs = net(test_inputs.float())
        loss_test = criterion(test_outputs, test_target.float())
        test_running_loss.append(loss_test.item()/b_size)
        
    print('Test:')
    print('running_loss_ave:', np.mean(test_running_loss))
        
    test_loss_list.append(np.mean(test_running_loss))  
    print('------------') 
            
print('Finished')
# Out:
# Train:
# epoch 1, batches 1, running_loss 2.324884338378906
# epoch 1, batches 5001, running_loss 0.5268012237548828
# Test:
# running_loss_ave: 0.90321941986084
# ------------
# Train:
# epoch 2, batches 1, running_loss 1.0239254760742187
# epoch 2, batches 5001, running_loss 0.8824677276611328
# Test:
# running_loss_ave: 0.6141206556892396
# ------------
# Train:
# epoch 3, batches 1, running_loss 0.5356432342529297
# epoch 3, batches 5001, running_loss 0.6341110610961914
# Test:
# running_loss_ave: 0.9135412203979493
# ------------
# Train:
# epoch 4, batches 1, running_loss 1.3616938781738281
# epoch 4, batches 5001, running_loss 0.9438521575927734
# Test:
# running_loss_ave: 0.8114773036956787
# ------------
# Train:
# epoch 5, batches 1, running_loss 0.5816484069824219
# epoch 5, batches 5001, running_loss 0.6662801361083984
# Test:
# running_loss_ave: 0.6859840060424804
# ------------
# Train:
# epoch 6, batches 1, running_loss 0.6372355651855469
# epoch 6, batches 5001, running_loss 0.795205078125
# Test:
# running_loss_ave: 0.8582431596374512
# ------------
# Train:
# epoch 7, batches 1, running_loss 0.887113037109375
# epoch 7, batches 5001, running_loss 1.3015370178222656
# Test:
# running_loss_ave: 0.8094895807266235
# ------------
# Train:
# epoch 8, batches 1, running_loss 0.6292771530151368
# epoch 8, batches 5001, running_loss 0.7400038146972656
# Test:
# running_loss_ave: 0.8337095110321046
# ------------
# Train:
# epoch 9, batches 1, running_loss 0.6792550659179688
# epoch 9, batches 5001, running_loss 0.793672103881836
# Test:
# running_loss_ave: 0.8271715445327757
# ------------
# Train:
# epoch 10, batches 1, running_loss 0.8434251403808594
# epoch 10, batches 5001, running_loss 0.6803217315673828
# Test:
# running_loss_ave: 0.866735672607422
# ------------
# Train:
# epoch 11, batches 1, running_loss 0.7558907318115234
# epoch 11, batches 5001, running_loss 0.6810890197753906
# Test:
# running_loss_ave: 0.8108535789108275
# ------------
# Train:
# epoch 12, batches 1, running_loss 0.944871826171875
# epoch 12, batches 5001, running_loss 0.8051941680908203
# Test:
# running_loss_ave: 0.8236697800064087
# ------------
# Train:
# epoch 13, batches 1, running_loss 0.5518392562866211
# epoch 13, batches 5001, running_loss 0.9876052856445312
# Test:
# running_loss_ave: 0.8605752236175538
# ------------
# Train:
# epoch 14, batches 1, running_loss 0.9251008605957032
# epoch 14, batches 5001, running_loss 0.6563357543945313
# Test:
# running_loss_ave: 0.8131999377441407
# ------------
# Train:
# epoch 15, batches 1, running_loss 0.8117096710205078
# epoch 15, batches 5001, running_loss 0.9713197326660157
# Test:
# running_loss_ave: 0.8718693785095215
# ------------
# Train:
# epoch 16, batches 1, running_loss 0.7129997253417969
# epoch 16, batches 5001, running_loss 1.0968146514892578
# Test:
# running_loss_ave: 0.862597201385498
# ------------
# Train:
# epoch 17, batches 1, running_loss 0.8809609985351563
# epoch 17, batches 5001, running_loss 0.6605288696289062
# Test:
# running_loss_ave: 0.38001536932945246
# ------------
# Train:
# epoch 18, batches 1, running_loss 0.30420005798339844
# epoch 18, batches 5001, running_loss 0.08379904747009277
# Test:
# running_loss_ave: 0.10007288494586945
# ------------
# Train:
# epoch 19, batches 1, running_loss 0.07773407936096191
# epoch 19, batches 5001, running_loss 0.11145631790161133
# Test:
# running_loss_ave: 0.07888950586557388
# ------------
# Train:
# epoch 20, batches 1, running_loss 0.08253289222717285
# epoch 20, batches 5001, running_loss 0.08828379631042481
# Test:
# running_loss_ave: 0.06930036674499512
# ------------
# Train:
# epoch 21, batches 1, running_loss 0.11853953361511231
# epoch 21, batches 5001, running_loss 0.059640331268310545
# Test:
# running_loss_ave: 0.07306325500249862
# ------------
# Train:
# epoch 22, batches 1, running_loss 0.05931240558624268
# epoch 22, batches 5001, running_loss 0.09444997787475586
# Test:
# running_loss_ave: 0.07251296031951904
# ------------
# Train:
# epoch 23, batches 1, running_loss 0.0801880931854248
# epoch 23, batches 5001, running_loss 0.07566348552703857
# Test:
# running_loss_ave: 0.06050952300548553
# ------------
# Train:
# epoch 24, batches 1, running_loss 0.06121719837188721
# epoch 24, batches 5001, running_loss 0.061007628440856936
# Test:
# running_loss_ave: 0.06701287094354628
# ------------
# Train:
# epoch 25, batches 1, running_loss 0.06585429668426514
# epoch 25, batches 5001, running_loss 0.12168613433837891
# Test:
# running_loss_ave: 0.09315578800678255
# ------------
# Train:
# epoch 26, batches 1, running_loss 0.049803762435913085
# epoch 26, batches 5001, running_loss 0.036683495044708254
# Test:
# running_loss_ave: 0.05394193127274513
# ------------
# Train:
# epoch 27, batches 1, running_loss 0.042007675170898436
# epoch 27, batches 5001, running_loss 0.0834027099609375
# Test:
# running_loss_ave: 0.12545733124732972
# ------------
# Train:
# epoch 28, batches 1, running_loss 0.08825728416442871
# epoch 28, batches 5001, running_loss 0.07117387771606445
# Test:
# running_loss_ave: 0.08268853917837143
# ------------
# Train:
# epoch 29, batches 1, running_loss 0.08866840362548828
# epoch 29, batches 5001, running_loss 0.12559622764587403
# Test:
# running_loss_ave: 0.3244029184341431
# ------------
# Train:
# epoch 30, batches 1, running_loss 0.18500785827636718
# epoch 30, batches 5001, running_loss 1.10943359375
# Test:
# running_loss_ave: 0.18379694041728975
# ------------
# Train:
# epoch 31, batches 1, running_loss 0.18815956115722657
# epoch 31, batches 5001, running_loss 0.11243050575256347
# Test:
# running_loss_ave: 0.09219691328287125
# ------------
# Train:
# epoch 32, batches 1, running_loss 0.09902310371398926
# epoch 32, batches 5001, running_loss 0.1063375186920166
# Test:
# running_loss_ave: 0.06582055227279664
# ------------
# Train:
# epoch 33, batches 1, running_loss 0.06279266357421875
# epoch 33, batches 5001, running_loss 0.08541852951049805
# Test:
# running_loss_ave: 0.06567706177949906
# ------------
# Train:
# epoch 34, batches 1, running_loss 0.09032701492309571
# epoch 34, batches 5001, running_loss 0.07402374267578125
# Test:
# running_loss_ave: 0.05672993000984192
# ------------
# Train:
# epoch 35, batches 1, running_loss 0.05637214183807373
# epoch 35, batches 5001, running_loss 0.037403428554534913
# Test:
# running_loss_ave: 0.0569338806772232
# ------------
# Train:
# epoch 36, batches 1, running_loss 0.04571981906890869
# epoch 36, batches 5001, running_loss 0.050150766372680664
# Test:
# running_loss_ave: 0.06143682047605515
# ------------
# Train:
# epoch 37, batches 1, running_loss 0.03768651008605957
# epoch 37, batches 5001, running_loss 0.058916845321655274
# Test:
# running_loss_ave: 0.047043215994834894
# ------------
# Train:
# epoch 38, batches 1, running_loss 0.04981654167175293
# epoch 38, batches 5001, running_loss 0.06285048007965088
# Test:
# running_loss_ave: 0.07040294748067856
# ------------
# Train:
# epoch 39, batches 1, running_loss 0.11849850654602051
# epoch 39, batches 5001, running_loss 0.05435330867767334
# Test:
# running_loss_ave: 0.04197183091759682
# ------------
# Train:
# epoch 40, batches 1, running_loss 0.04100658893585205
# epoch 40, batches 5001, running_loss 0.06640791893005371
# Test:
# running_loss_ave: 0.056745323219299315
# ------------
# Train:
# epoch 41, batches 1, running_loss 0.06279789924621582
# epoch 41, batches 5001, running_loss 0.0431470775604248
# Test:
# running_loss_ave: 0.10769255895137787
# ------------
# Train:
# epoch 42, batches 1, running_loss 0.07971056461334229
# epoch 42, batches 5001, running_loss 0.07619450092315674
# Test:
# running_loss_ave: 0.048616644886732105
# ------------
# Train:
# epoch 43, batches 1, running_loss 0.048933701515197756
# epoch 43, batches 5001, running_loss 0.03305335521697998
# Test:
# running_loss_ave: 0.06964677639484405
# ------------
# Train:
# epoch 44, batches 1, running_loss 0.049718408584594725
# epoch 44, batches 5001, running_loss 0.04187179088592529
# Test:
# running_loss_ave: 0.10554400375366212
# ------------
# Train:
# epoch 45, batches 1, running_loss 0.09802169799804687
# epoch 45, batches 5001, running_loss 0.08785788536071777
# Test:
# running_loss_ave: 0.04810635187864303
# ------------
# Train:
# epoch 46, batches 1, running_loss 0.044840989112854
# epoch 46, batches 5001, running_loss 0.03569689035415649
# Test:
# running_loss_ave: 0.0483319191634655
# ------------
# Train:
# epoch 47, batches 1, running_loss 0.0365177321434021
# epoch 47, batches 5001, running_loss 0.030344674587249754
# Test:
# running_loss_ave: 0.045378549097776416
# ------------
# Train:
# epoch 48, batches 1, running_loss 0.032037878036499025
# epoch 48, batches 5001, running_loss 0.042396259307861325
# Test:
# running_loss_ave: 0.03539153772115708
# ------------
# Train:
# epoch 49, batches 1, running_loss 0.03430635690689087
# epoch 49, batches 5001, running_loss 0.027867615222930908
# Test:
# running_loss_ave: 0.03564284835577011
# ------------
# Train:
# epoch 50, batches 1, running_loss 0.02641587734222412
# epoch 50, batches 5001, running_loss 0.03604313850402832
# Test:
# running_loss_ave: 0.036657538759708404
# ------------
# Finished

# %%
# Plot

import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(train_loss_list, c='r', label = 'Train')
plt.plot(test_loss_list, c='g', label = 'Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Test result
stock_price_test_BS = np.arange(20, 80, 0.1)
stock_price_test_NN = np.arange(20, 80, 1)

Option_BS_model = []
Option_NN_model = []

for i,S1 in enumerate(stock_price_test_BS):
  Option_BS_model.append(euro_option(S1, 50, 1, 0.06, 0.2, 'call'))

for j,S2 in enumerate(stock_price_test_NN):

  Option_NN_model.append(net(torch.tensor([[S2, 50, 1, 0.06, 0.2, 1, 0]], device = 'cuda: 0')).item())

plt.figure(figsize=(12,8))
plt.plot(stock_price_test_BS, Option_BS_model, c='r', label = 'Black-Schole')
plt.plot(stock_price_test_NN, Option_NN_model, c='g',linestyle = ':', linewidth = 8, label = 'DNN')
plt.xlabel('Stock price')
plt.ylabel('Call option price')
plt.legend()
plt.show()
